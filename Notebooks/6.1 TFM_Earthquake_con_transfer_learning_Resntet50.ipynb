# %% [markdown]
# ## **Transfer Learning**

# %% [markdown]
# https://keras.io/applications/
#
# Redes preentrenadas que se pueden descargar directamente en Keras:
#
# * Xception
# * VGG16
# * VGG19
# * ResNet
# * ResNetV2
# * InceptionV3
# * InceptionResNetV2
# * MobileNet
# * MobileNetV2
# * DenseNet
# * NASNet
#
# Algunas requieren un tamaño de imagen de entrada fijo, otras no.

# %%
COLAB = True

# %%
#!pip install pillow==8.0.0

# %%
if COLAB:
    # %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# En parte de:
# https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html

# %%
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.models import Sequential, load_model, Model
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras import backend as K
from keras.callbacks import ModelCheckpoint
from keras import regularizers
from glob import glob

import matplotlib.pyplot as plt
import numpy as np

from IPython.display import SVG, display, clear_output
from keras.utils.vis_utils import model_to_dot

from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# !ls
# Out:
# sample_data

# %%
if COLAB:
    from google_drive_downloader import GoogleDriveDownloader as gdd
    gdd.download_file_from_google_drive(file_id='1EETTDTH5Wv-hZ1tKDpGHYPvAGPQ51gC6',
                                        dest_path='./seg_train.zip', unzip=True)
    gdd.download_file_from_google_drive(file_id='1UI8dSvyJ4OVT7NiF4cYdoAfjYH6Lj76D',
                                        dest_path='./seg_test.zip', unzip=True)
    

    #https://drive.google.com/file/d/1EETTDTH5Wv-hZ1tKDpGHYPvAGPQ51gC6/view?usp=sharing
    #https://drive.google.com/file/d/1EETTDTH5Wv-hZ1tKDpGHYPvAGPQ51gC6/view?usp=sharing

    #https://drive.google.com/file/d/1UI8dSvyJ4OVT7NiF4cYdoAfjYH6Lj76D/view?usp=sharing
# Out:
# Downloading 1EETTDTH5Wv-hZ1tKDpGHYPvAGPQ51gC6 into ./seg_train.zip... Done.
# Unzipping...Done.
# Downloading 1UI8dSvyJ4OVT7NiF4cYdoAfjYH6Lj76D into ./seg_test.zip... Done.
# Unzipping...Done.

# %%
# !ls
# Out:
# sample_data  seg_test  seg_test.zip  seg_train	seg_train.zip

# %%
# !ls seg_train
# Out:
# mild  none  severe

# %%
# !ls seg_test
# Out:
# mild  none  severe

# %%
# !ls seg_train/severe/
# Out:
# nepal_eq_severe_im_10000.jpg  nepal_eq_severe_im_24778.jpg
# nepal_eq_severe_im_10004.jpg  nepal_eq_severe_im_24782.jpg
# nepal_eq_severe_im_10007.jpg  nepal_eq_severe_im_24785.jpg
# nepal_eq_severe_im_1000.jpg   nepal_eq_severe_im_24798.jpg
# nepal_eq_severe_im_10015.jpg  nepal_eq_severe_im_24801.jpg
# nepal_eq_severe_im_10016.jpg  nepal_eq_severe_im_24802.jpg
# nepal_eq_severe_im_1004.jpg   nepal_eq_severe_im_24834.jpg
# nepal_eq_severe_im_1005.jpg   nepal_eq_severe_im_24858.jpg
# nepal_eq_severe_im_1009.jpg   nepal_eq_severe_im_24878.jpg
# nepal_eq_severe_im_100.jpg    nepal_eq_severe_im_24880.jpg
# nepal_eq_severe_im_1017.jpg   nepal_eq_severe_im_24889.jpg
# nepal_eq_severe_im_1018.jpg   nepal_eq_severe_im_24897.jpg
# nepal_eq_severe_im_101.jpg    nepal_eq_severe_im_24901.jpg
# nepal_eq_severe_im_10206.jpg  nepal_eq_severe_im_24905.jpg
# nepal_eq_severe_im_10216.jpg  nepal_eq_severe_im_24927.jpg
# nepal_eq_severe_im_10218.jpg  nepal_eq_severe_im_24929.jpg
# nepal_eq_severe_im_10225.jpg  nepal_eq_severe_im_24930.jpg
# nepal_eq_severe_im_10227.jpg  nepal_eq_severe_im_24936.jpg
# nepal_eq_severe_im_10228.jpg  nepal_eq_severe_im_24984.jpg
# nepal_eq_severe_im_10233.jpg  nepal_eq_severe_im_24985.jpg
# nepal_eq_severe_im_10234.jpg  nepal_eq_severe_im_24986.jpg
# nepal_eq_severe_im_10237.jpg  nepal_eq_severe_im_24989.jpg
# nepal_eq_severe_im_10244.jpg  nepal_eq_severe_im_24990.jpg
# nepal_eq_severe_im_10245.jpg  nepal_eq_severe_im_25025.jpg
# nepal_eq_severe_im_10247.jpg  nepal_eq_severe_im_25027.jpg
# nepal_eq_severe_im_10248.jpg  nepal_eq_severe_im_25028.jpg
# nepal_eq_severe_im_10249.jpg  nepal_eq_severe_im_25031.jpg
# nepal_eq_severe_im_10251.jpg  nepal_eq_severe_im_25033.jpg
# nepal_eq_severe_im_10258.jpg  nepal_eq_severe_im_25036.jpg
# nepal_eq_severe_im_10259.jpg  nepal_eq_severe_im_25042.jpg
# nepal_eq_severe_im_10272.jpg  nepal_eq_severe_im_25068.jpg
# nepal_eq_severe_im_10274.jpg  nepal_eq_severe_im_25069.jpg
# nepal_eq_severe_im_10275.jpg  nepal_eq_severe_im_25073.jpg
# nepal_eq_severe_im_10276.jpg  nepal_eq_severe_im_25074.jpg
# nepal_eq_severe_im_10284.jpg  nepal_eq_severe_im_25075.jpg
# nepal_eq_severe_im_10285.jpg  nepal_eq_severe_im_25077.jpg
# nepal_eq_severe_im_10287.jpg  nepal_eq_severe_im_25083.jpg
# nepal_eq_severe_im_10288.jpg  nepal_eq_severe_im_25084.jpg
# nepal_eq_severe_im_10289.jpg  nepal_eq_severe_im_25085.jpg
# nepal_eq_severe_im_1029.jpg   nepal_eq_severe_im_25089.jpg
# nepal_eq_severe_im_10314.jpg  nepal_eq_severe_im_250.jpg
# nepal_eq_severe_im_10316.jpg  nepal_eq_severe_im_25100.jpg
# nepal_eq_severe_im_10317.jpg  nepal_eq_severe_im_25103.jpg
# nepal_eq_severe_im_10319.jpg  nepal_eq_severe_im_25106.jpg
# nepal_eq_severe_im_10320.jpg  nepal_eq_severe_im_25108.jpg
# nepal_eq_severe_im_10321.jpg  nepal_eq_severe_im_25111.jpg
# nepal_eq_severe_im_10322.jpg  nepal_eq_severe_im_25156.jpg
# nepal_eq_severe_im_10323.jpg  nepal_eq_severe_im_25159.jpg
# nepal_eq_severe_im_10324.jpg  nepal_eq_severe_im_25162.jpg
# nepal_eq_severe_im_10325.jpg  nepal_eq_severe_im_25165.jpg
# nepal_eq_severe_im_10326.jpg  nepal_eq_severe_im_25169.jpg
# nepal_eq_severe_im_10327.jpg  nepal_eq_severe_im_25170.jpg
# nepal_eq_severe_im_10328.jpg  nepal_eq_severe_im_25172.jpg
# nepal_eq_severe_im_10329.jpg  nepal_eq_severe_im_25177.jpg
# nepal_eq_severe_im_10330.jpg  nepal_eq_severe_im_25179.jpg
# nepal_eq_severe_im_10331.jpg  nepal_eq_severe_im_25182.jpg
# nepal_eq_severe_im_10332.jpg  nepal_eq_severe_im_25183.jpg
# nepal_eq_severe_im_10333.jpg  nepal_eq_severe_im_25186.jpg
# nepal_eq_severe_im_10336.jpg  nepal_eq_severe_im_25195.jpg
# nepal_eq_severe_im_10337.jpg  nepal_eq_severe_im_25196.jpg
# nepal_eq_severe_im_1033.jpg   nepal_eq_severe_im_25198.jpg
# nepal_eq_severe_im_10340.jpg  nepal_eq_severe_im_25200.jpg
# nepal_eq_severe_im_10341.jpg  nepal_eq_severe_im_25213.jpg
# nepal_eq_severe_im_10344.jpg  nepal_eq_severe_im_25214.jpg
# nepal_eq_severe_im_10348.jpg  nepal_eq_severe_im_25215.jpg
# nepal_eq_severe_im_10355.jpg  nepal_eq_severe_im_25217.jpg
# nepal_eq_severe_im_10356.jpg  nepal_eq_severe_im_25218.jpg
# nepal_eq_severe_im_10367.jpg  nepal_eq_severe_im_25219.jpg
# nepal_eq_severe_im_1036.jpg   nepal_eq_severe_im_25220.jpg
# nepal_eq_severe_im_10376.jpg  nepal_eq_severe_im_25221.jpg
# nepal_eq_severe_im_10377.jpg  nepal_eq_severe_im_25225.jpg
# nepal_eq_severe_im_10378.jpg  nepal_eq_severe_im_25227.jpg
# nepal_eq_severe_im_10379.jpg  nepal_eq_severe_im_25228.jpg
# nepal_eq_severe_im_10387.jpg  nepal_eq_severe_im_25229.jpg
# nepal_eq_severe_im_10388.jpg  nepal_eq_severe_im_25235.jpg
# nepal_eq_severe_im_10389.jpg  nepal_eq_severe_im_25253.jpg
# nepal_eq_severe_im_10390.jpg  nepal_eq_severe_im_252.jpg
# nepal_eq_severe_im_10391.jpg  nepal_eq_severe_im_25356.jpg
# nepal_eq_severe_im_10394.jpg  nepal_eq_severe_im_25357.jpg
# nepal_eq_severe_im_10395.jpg  nepal_eq_severe_im_25358.jpg
# nepal_eq_severe_im_103.jpg    nepal_eq_severe_im_25359.jpg
# nepal_eq_severe_im_10402.jpg  nepal_eq_severe_im_25398.jpg
# nepal_eq_severe_im_10403.jpg  nepal_eq_severe_im_253.jpg
# nepal_eq_severe_im_10405.jpg  nepal_eq_severe_im_25415.jpg
# nepal_eq_severe_im_10406.jpg  nepal_eq_severe_im_25416.jpg
# nepal_eq_severe_im_10408.jpg  nepal_eq_severe_im_25418.jpg
# nepal_eq_severe_im_1040.jpg   nepal_eq_severe_im_25424.jpg
# nepal_eq_severe_im_10410.jpg  nepal_eq_severe_im_25425.jpg
# nepal_eq_severe_im_10411.jpg  nepal_eq_severe_im_25431.jpg
# nepal_eq_severe_im_10412.jpg  nepal_eq_severe_im_25433.jpg
# nepal_eq_severe_im_10414.jpg  nepal_eq_severe_im_25438.jpg
# nepal_eq_severe_im_10416.jpg  nepal_eq_severe_im_25441.jpg
# nepal_eq_severe_im_10417.jpg  nepal_eq_severe_im_25444.jpg
# nepal_eq_severe_im_10424.jpg  nepal_eq_severe_im_25450.jpg
# nepal_eq_severe_im_10426.jpg  nepal_eq_severe_im_25454.jpg
# nepal_eq_severe_im_10431.jpg  nepal_eq_severe_im_25455.jpg
# nepal_eq_severe_im_10435.jpg  nepal_eq_severe_im_25456.jpg
# nepal_eq_severe_im_10439.jpg  nepal_eq_severe_im_25457.jpg
# nepal_eq_severe_im_1047.jpg   nepal_eq_severe_im_25459.jpg
# nepal_eq_severe_im_10490.jpg  nepal_eq_severe_im_25461.jpg
# nepal_eq_severe_im_10491.jpg  nepal_eq_severe_im_25462.jpg
# nepal_eq_severe_im_10494.jpg  nepal_eq_severe_im_25464.jpg
# nepal_eq_severe_im_10495.jpg  nepal_eq_severe_im_25466.jpg
# nepal_eq_severe_im_10498.jpg  nepal_eq_severe_im_25468.jpg
# nepal_eq_severe_im_10507.jpg  nepal_eq_severe_im_25470.jpg
# nepal_eq_severe_im_10509.jpg  nepal_eq_severe_im_25474.jpg
# nepal_eq_severe_im_10510.jpg  nepal_eq_severe_im_25476.jpg
# nepal_eq_severe_im_10520.jpg  nepal_eq_severe_im_25494.jpg
# nepal_eq_severe_im_10521.jpg  nepal_eq_severe_im_25497.jpg
# nepal_eq_severe_im_10523.jpg  nepal_eq_severe_im_254.jpg
# nepal_eq_severe_im_10524.jpg  nepal_eq_severe_im_25500.jpg
# nepal_eq_severe_im_10526.jpg  nepal_eq_severe_im_25501.jpg
# nepal_eq_severe_im_10528.jpg  nepal_eq_severe_im_25503.jpg
# nepal_eq_severe_im_10529.jpg  nepal_eq_severe_im_25504.jpg
# nepal_eq_severe_im_10544.jpg  nepal_eq_severe_im_25522.jpg
# nepal_eq_severe_im_10545.jpg  nepal_eq_severe_im_25530.jpg
# nepal_eq_severe_im_10572.jpg  nepal_eq_severe_im_25536.jpg
# nepal_eq_severe_im_10582.jpg  nepal_eq_severe_im_25537.jpg
# nepal_eq_severe_im_10583.jpg  nepal_eq_severe_im_25539.jpg
# nepal_eq_severe_im_10592.jpg  nepal_eq_severe_im_25540.jpg
# nepal_eq_severe_im_10593.jpg  nepal_eq_severe_im_25547.jpg
# nepal_eq_severe_im_10599.jpg  nepal_eq_severe_im_25549.jpg
# nepal_eq_severe_im_10601.jpg  nepal_eq_severe_im_25552.jpg
# nepal_eq_severe_im_10602.jpg  nepal_eq_severe_im_25559.jpg
# nepal_eq_severe_im_10609.jpg  nepal_eq_severe_im_25564.jpg
# nepal_eq_severe_im_10611.jpg  nepal_eq_severe_im_25566.jpg
# nepal_eq_severe_im_10625.jpg  nepal_eq_severe_im_25567.jpg
# nepal_eq_severe_im_10644.jpg  nepal_eq_severe_im_25568.jpg
# nepal_eq_severe_im_10648.jpg  nepal_eq_severe_im_25573.jpg
# nepal_eq_severe_im_10651.jpg  nepal_eq_severe_im_25582.jpg
# nepal_eq_severe_im_10656.jpg  nepal_eq_severe_im_25587.jpg
# nepal_eq_severe_im_1065.jpg   nepal_eq_severe_im_255.jpg
# nepal_eq_severe_im_10660.jpg  nepal_eq_severe_im_25615.jpg
# nepal_eq_severe_im_1066.jpg   nepal_eq_severe_im_25618.jpg
# nepal_eq_severe_im_10690.jpg  nepal_eq_severe_im_2561.jpg
# nepal_eq_severe_im_10729.jpg  nepal_eq_severe_im_25622.jpg
# nepal_eq_severe_im_10742.jpg  nepal_eq_severe_im_25624.jpg
# nepal_eq_severe_im_10743.jpg  nepal_eq_severe_im_25627.jpg
# nepal_eq_severe_im_10746.jpg  nepal_eq_severe_im_25628.jpg
# nepal_eq_severe_im_1076.jpg   nepal_eq_severe_im_25630.jpg
# nepal_eq_severe_im_10773.jpg  nepal_eq_severe_im_25631.jpg
# nepal_eq_severe_im_10778.jpg  nepal_eq_severe_im_25634.jpg
# nepal_eq_severe_im_10788.jpg  nepal_eq_severe_im_25638.jpg
# nepal_eq_severe_im_10789.jpg  nepal_eq_severe_im_25640.jpg
# nepal_eq_severe_im_10790.jpg  nepal_eq_severe_im_25641.jpg
# nepal_eq_severe_im_10791.jpg  nepal_eq_severe_im_25643.jpg
# nepal_eq_severe_im_10793.jpg  nepal_eq_severe_im_25645.jpg
# nepal_eq_severe_im_10795.jpg  nepal_eq_severe_im_25646.jpg
# nepal_eq_severe_im_10797.jpg  nepal_eq_severe_im_25648.jpg
# nepal_eq_severe_im_10798.jpg  nepal_eq_severe_im_25649.jpg
# nepal_eq_severe_im_107.jpg    nepal_eq_severe_im_25652.jpg
# nepal_eq_severe_im_10801.jpg  nepal_eq_severe_im_25654.jpg
# nepal_eq_severe_im_10804.jpg  nepal_eq_severe_im_25655.jpg
# nepal_eq_severe_im_10806.jpg  nepal_eq_severe_im_25664.jpg
# nepal_eq_severe_im_10812.jpg  nepal_eq_severe_im_25665.jpg
# nepal_eq_severe_im_10817.jpg  nepal_eq_severe_im_25671.jpg
# nepal_eq_severe_im_10819.jpg  nepal_eq_severe_im_25677.jpg
# nepal_eq_severe_im_10820.jpg  nepal_eq_severe_im_25679.jpg
# nepal_eq_severe_im_10832.jpg  nepal_eq_severe_im_25687.jpg
# nepal_eq_severe_im_10834.jpg  nepal_eq_severe_im_25692.jpg
# nepal_eq_severe_im_10837.jpg  nepal_eq_severe_im_256.jpg
# nepal_eq_severe_im_10848.jpg  nepal_eq_severe_im_25741.jpg
# nepal_eq_severe_im_1084.jpg   nepal_eq_severe_im_25769.jpg
# nepal_eq_severe_im_10850.jpg  nepal_eq_severe_im_25770.jpg
# nepal_eq_severe_im_10851.jpg  nepal_eq_severe_im_25771.jpg
# nepal_eq_severe_im_10854.jpg  nepal_eq_severe_im_25773.jpg
# nepal_eq_severe_im_10855.jpg  nepal_eq_severe_im_25774.jpg
# nepal_eq_severe_im_10861.jpg  nepal_eq_severe_im_25776.jpg
# nepal_eq_severe_im_1086.jpg   nepal_eq_severe_im_25778.jpg
# nepal_eq_severe_im_10871.jpg  nepal_eq_severe_im_25786.jpg
# nepal_eq_severe_im_10872.jpg  nepal_eq_severe_im_25795.jpg
# nepal_eq_severe_im_10873.jpg  nepal_eq_severe_im_25796.jpg
# nepal_eq_severe_im_1087.jpg   nepal_eq_severe_im_25799.jpg
# nepal_eq_severe_im_10905.jpg  nepal_eq_severe_im_25801.jpg
# nepal_eq_severe_im_10906.jpg  nepal_eq_severe_im_25802.jpg
# nepal_eq_severe_im_10909.jpg  nepal_eq_severe_im_25803.jpg
# nepal_eq_severe_im_10911.jpg  nepal_eq_severe_im_25806.jpg
# nepal_eq_severe_im_10913.jpg  nepal_eq_severe_im_25807.jpg
# nepal_eq_severe_im_10919.jpg  nepal_eq_severe_im_25809.jpg
# nepal_eq_severe_im_10920.jpg  nepal_eq_severe_im_25811.jpg
# nepal_eq_severe_im_10929.jpg  nepal_eq_severe_im_25815.jpg
# nepal_eq_severe_im_1092.jpg   nepal_eq_severe_im_25817.jpg
# nepal_eq_severe_im_10941.jpg  nepal_eq_severe_im_25819.jpg
# nepal_eq_severe_im_10950.jpg  nepal_eq_severe_im_25821.jpg
# nepal_eq_severe_im_10960.jpg  nepal_eq_severe_im_25850.jpg
# nepal_eq_severe_im_10961.jpg  nepal_eq_severe_im_25851.jpg
# nepal_eq_severe_im_10962.jpg  nepal_eq_severe_im_25852.jpg
# nepal_eq_severe_im_10963.jpg  nepal_eq_severe_im_25853.jpg
# nepal_eq_severe_im_10966.jpg  nepal_eq_severe_im_25856.jpg
# nepal_eq_severe_im_10967.jpg  nepal_eq_severe_im_25865.jpg
# nepal_eq_severe_im_10968.jpg  nepal_eq_severe_im_25866.jpg
# nepal_eq_severe_im_10970.jpg  nepal_eq_severe_im_25867.jpg
# nepal_eq_severe_im_10971.jpg  nepal_eq_severe_im_25868.jpg
# nepal_eq_severe_im_10972.jpg  nepal_eq_severe_im_25870.jpg
# nepal_eq_severe_im_10973.jpg  nepal_eq_severe_im_25871.jpg
# nepal_eq_severe_im_10975.jpg  nepal_eq_severe_im_25873.jpg
# nepal_eq_severe_im_10978.jpg  nepal_eq_severe_im_25900.jpg
# nepal_eq_severe_im_10987.jpg  nepal_eq_severe_im_25902.jpg
# nepal_eq_severe_im_10990.jpg  nepal_eq_severe_im_25903.jpg
# nepal_eq_severe_im_10991.jpg  nepal_eq_severe_im_25904.jpg
# nepal_eq_severe_im_10993.jpg  nepal_eq_severe_im_25906.jpg
# nepal_eq_severe_im_10994.jpg  nepal_eq_severe_im_25907.jpg
# nepal_eq_severe_im_10995.jpg  nepal_eq_severe_im_25908.jpg
# nepal_eq_severe_im_11007.jpg  nepal_eq_severe_im_25909.jpg
# nepal_eq_severe_im_11008.jpg  nepal_eq_severe_im_25910.jpg
# nepal_eq_severe_im_11009.jpg  nepal_eq_severe_im_25911.jpg
# nepal_eq_severe_im_11037.jpg  nepal_eq_severe_im_25912.jpg
# nepal_eq_severe_im_11038.jpg  nepal_eq_severe_im_25968.jpg
# nepal_eq_severe_im_11550.jpg  nepal_eq_severe_im_34165.jpg
# nepal_eq_severe_im_11552.jpg  nepal_eq_severe_im_34200.jpg
# nepal_eq_severe_im_11558.jpg  nepal_eq_severe_im_34204.jpg
# nepal_eq_severe_im_11559.jpg  nepal_eq_severe_im_34210.jpg
# nepal_eq_severe_im_11560.jpg  nepal_eq_severe_im_34221.jpg
# nepal_eq_severe_im_11562.jpg  nepal_eq_severe_im_34222.jpg
# nepal_eq_severe_im_11568.jpg  nepal_eq_severe_im_34256.jpg
# nepal_eq_severe_im_11570.jpg  nepal_eq_severe_im_34296.jpg
# nepal_eq_severe_im_11571.jpg  nepal_eq_severe_im_34298.jpg
# nepal_eq_severe_im_11576.jpg  nepal_eq_severe_im_34299.jpg
# nepal_eq_severe_im_11584.jpg  nepal_eq_severe_im_34301.jpg
# nepal_eq_severe_im_11585.jpg  nepal_eq_severe_im_34303.jpg
# nepal_eq_severe_im_11586.jpg  nepal_eq_severe_im_34306.jpg
# nepal_eq_severe_im_11587.jpg  nepal_eq_severe_im_34309.jpg
# nepal_eq_severe_im_11590.jpg  nepal_eq_severe_im_34310.jpg
# nepal_eq_severe_im_11591.jpg  nepal_eq_severe_im_34316.jpg
# nepal_eq_severe_im_11593.jpg  nepal_eq_severe_im_34319.jpg
# nepal_eq_severe_im_11594.jpg  nepal_eq_severe_im_34328.jpg
# nepal_eq_severe_im_11600.jpg  nepal_eq_severe_im_34330.jpg
# nepal_eq_severe_im_11601.jpg  nepal_eq_severe_im_34404.jpg
# nepal_eq_severe_im_11610.jpg  nepal_eq_severe_im_34407.jpg
# nepal_eq_severe_im_1161.jpg   nepal_eq_severe_im_34408.jpg
# nepal_eq_severe_im_11634.jpg  nepal_eq_severe_im_34414.jpg
# nepal_eq_severe_im_11636.jpg  nepal_eq_severe_im_34415.jpg
# nepal_eq_severe_im_11637.jpg  nepal_eq_severe_im_34416.jpg
# nepal_eq_severe_im_11639.jpg  nepal_eq_severe_im_34446.jpg
# nepal_eq_severe_im_11641.jpg  nepal_eq_severe_im_34448.jpg
# nepal_eq_severe_im_11647.jpg  nepal_eq_severe_im_34469.jpg
# nepal_eq_severe_im_11650.jpg  nepal_eq_severe_im_34470.jpg
# nepal_eq_severe_im_11651.jpg  nepal_eq_severe_im_34488.jpg
# nepal_eq_severe_im_11652.jpg  nepal_eq_severe_im_34499.jpg
# nepal_eq_severe_im_11653.jpg  nepal_eq_severe_im_34502.jpg
# nepal_eq_severe_im_11654.jpg  nepal_eq_severe_im_34503.jpg
# nepal_eq_severe_im_11656.jpg  nepal_eq_severe_im_34519.jpg
# nepal_eq_severe_im_11657.jpg  nepal_eq_severe_im_3451.jpg
# nepal_eq_severe_im_11659.jpg  nepal_eq_severe_im_34532.jpg
# nepal_eq_severe_im_1165.jpg   nepal_eq_severe_im_34546.jpg
# nepal_eq_severe_im_11661.jpg  nepal_eq_severe_im_34548.jpg
# nepal_eq_severe_im_11663.jpg  nepal_eq_severe_im_34561.jpg
# nepal_eq_severe_im_11666.jpg  nepal_eq_severe_im_34562.jpg
# nepal_eq_severe_im_11669.jpg  nepal_eq_severe_im_34590.jpg
# nepal_eq_severe_im_11670.jpg  nepal_eq_severe_im_34591.jpg
# nepal_eq_severe_im_11673.jpg  nepal_eq_severe_im_34595.jpg
# nepal_eq_severe_im_11674.jpg  nepal_eq_severe_im_34596.jpg
# nepal_eq_severe_im_11677.jpg  nepal_eq_severe_im_34597.jpg
# nepal_eq_severe_im_11679.jpg  nepal_eq_severe_im_34601.jpg
# nepal_eq_severe_im_1167.jpg   nepal_eq_severe_im_34602.jpg
# nepal_eq_severe_im_11680.jpg  nepal_eq_severe_im_34603.jpg
# nepal_eq_severe_im_11683.jpg  nepal_eq_severe_im_34618.jpg
# nepal_eq_severe_im_11684.jpg  nepal_eq_severe_im_34625.jpg
# nepal_eq_severe_im_11686.jpg  nepal_eq_severe_im_34629.jpg
# nepal_eq_severe_im_1168.jpg   nepal_eq_severe_im_34630.jpg
# nepal_eq_severe_im_11691.jpg  nepal_eq_severe_im_34631.jpg
# nepal_eq_severe_im_1169.jpg   nepal_eq_severe_im_34697.jpg
# nepal_eq_severe_im_116.jpg    nepal_eq_severe_im_34698.jpg
# nepal_eq_severe_im_11702.jpg  nepal_eq_severe_im_34701.jpg
# nepal_eq_severe_im_11706.jpg  nepal_eq_severe_im_34729.jpg
# nepal_eq_severe_im_11708.jpg  nepal_eq_severe_im_34730.jpg
# nepal_eq_severe_im_11711.jpg  nepal_eq_severe_im_34732.jpg
# nepal_eq_severe_im_11712.jpg  nepal_eq_severe_im_34867.jpg
# nepal_eq_severe_im_11714.jpg  nepal_eq_severe_im_34868.jpg
# nepal_eq_severe_im_11716.jpg  nepal_eq_severe_im_34869.jpg
# nepal_eq_severe_im_11718.jpg  nepal_eq_severe_im_35185.jpg
# nepal_eq_severe_im_11719.jpg  nepal_eq_severe_im_35188.jpg
# nepal_eq_severe_im_11720.jpg  nepal_eq_severe_im_35193.jpg
# nepal_eq_severe_im_11721.jpg  nepal_eq_severe_im_35195.jpg
# nepal_eq_severe_im_11722.jpg  nepal_eq_severe_im_35209.jpg
# nepal_eq_severe_im_11723.jpg  nepal_eq_severe_im_35212.jpg
# nepal_eq_severe_im_11728.jpg  nepal_eq_severe_im_35214.jpg
# nepal_eq_severe_im_11729.jpg  nepal_eq_severe_im_35227.jpg
# nepal_eq_severe_im_1172.jpg   nepal_eq_severe_im_35233.jpg
# nepal_eq_severe_im_11734.jpg  nepal_eq_severe_im_35240.jpg
# nepal_eq_severe_im_11736.jpg  nepal_eq_severe_im_35244.jpg
# nepal_eq_severe_im_11738.jpg  nepal_eq_severe_im_35248.jpg
# nepal_eq_severe_im_11739.jpg  nepal_eq_severe_im_3525.jpg
# nepal_eq_severe_im_11740.jpg  nepal_eq_severe_im_35287.jpg
# nepal_eq_severe_im_11741.jpg  nepal_eq_severe_im_35288.jpg
# nepal_eq_severe_im_11743.jpg  nepal_eq_severe_im_35293.jpg
# nepal_eq_severe_im_11748.jpg  nepal_eq_severe_im_35294.jpg
# nepal_eq_severe_im_11749.jpg  nepal_eq_severe_im_35296.jpg
# nepal_eq_severe_im_1174.jpg   nepal_eq_severe_im_35297.jpg
# nepal_eq_severe_im_11751.jpg  nepal_eq_severe_im_35299.jpg
# nepal_eq_severe_im_11752.jpg  nepal_eq_severe_im_35305.jpg
# nepal_eq_severe_im_11754.jpg  nepal_eq_severe_im_35309.jpg
# nepal_eq_severe_im_11756.jpg  nepal_eq_severe_im_35319.jpg
# nepal_eq_severe_im_11757.jpg  nepal_eq_severe_im_35321.jpg
# nepal_eq_severe_im_11759.jpg  nepal_eq_severe_im_35322.jpg
# nepal_eq_severe_im_11762.jpg  nepal_eq_severe_im_35327.jpg
# nepal_eq_severe_im_11770.jpg  nepal_eq_severe_im_35332.jpg
# nepal_eq_severe_im_11772.jpg  nepal_eq_severe_im_35333.jpg
# nepal_eq_severe_im_11774.jpg  nepal_eq_severe_im_35336.jpg
# nepal_eq_severe_im_11775.jpg  nepal_eq_severe_im_35337.jpg
# nepal_eq_severe_im_11784.jpg  nepal_eq_severe_im_35339.jpg
# nepal_eq_severe_im_11788.jpg  nepal_eq_severe_im_35359.jpg
# nepal_eq_severe_im_11796.jpg  nepal_eq_severe_im_3536.jpg
# nepal_eq_severe_im_11816.jpg  nepal_eq_severe_im_35374.jpg
# nepal_eq_severe_im_11821.jpg  nepal_eq_severe_im_35375.jpg
# nepal_eq_severe_im_11823.jpg  nepal_eq_severe_im_35376.jpg
# nepal_eq_severe_im_11831.jpg  nepal_eq_severe_im_35382.jpg
# nepal_eq_severe_im_11832.jpg  nepal_eq_severe_im_35384.jpg
# nepal_eq_severe_im_11833.jpg  nepal_eq_severe_im_35385.jpg
# nepal_eq_severe_im_11836.jpg  nepal_eq_severe_im_35386.jpg
# nepal_eq_severe_im_11847.jpg  nepal_eq_severe_im_3538.jpg
# nepal_eq_severe_im_11851.jpg  nepal_eq_severe_im_35405.jpg
# nepal_eq_severe_im_11852.jpg  nepal_eq_severe_im_35407.jpg
# nepal_eq_severe_im_11853.jpg  nepal_eq_severe_im_35408.jpg
# nepal_eq_severe_im_11855.jpg  nepal_eq_severe_im_3540.jpg
# nepal_eq_severe_im_11858.jpg  nepal_eq_severe_im_35413.jpg
# nepal_eq_severe_im_11864.jpg  nepal_eq_severe_im_35415.jpg
# nepal_eq_severe_im_11868.jpg  nepal_eq_severe_im_3541.jpg
# nepal_eq_severe_im_11869.jpg  nepal_eq_severe_im_35447.jpg
# nepal_eq_severe_im_11874.jpg  nepal_eq_severe_im_35486.jpg
# nepal_eq_severe_im_11879.jpg  nepal_eq_severe_im_35522.jpg
# nepal_eq_severe_im_11887.jpg  nepal_eq_severe_im_35527.jpg
# nepal_eq_severe_im_11902.jpg  nepal_eq_severe_im_35571.jpg
# nepal_eq_severe_im_11907.jpg  nepal_eq_severe_im_35572.jpg
# nepal_eq_severe_im_11919.jpg  nepal_eq_severe_im_35573.jpg
# nepal_eq_severe_im_1191.jpg   nepal_eq_severe_im_35590.jpg
# nepal_eq_severe_im_11922.jpg  nepal_eq_severe_im_35591.jpg
# nepal_eq_severe_im_1192.jpg   nepal_eq_severe_im_35597.jpg
# nepal_eq_severe_im_11930.jpg  nepal_eq_severe_im_35598.jpg
# nepal_eq_severe_im_11933.jpg  nepal_eq_severe_im_35603.jpg
# nepal_eq_severe_im_11934.jpg  nepal_eq_severe_im_35608.jpg
# nepal_eq_severe_im_11943.jpg  nepal_eq_severe_im_35609.jpg
# nepal_eq_severe_im_11972.jpg  nepal_eq_severe_im_35612.jpg
# nepal_eq_severe_im_11978.jpg  nepal_eq_severe_im_35613.jpg
# nepal_eq_severe_im_11979.jpg  nepal_eq_severe_im_35614.jpg
# nepal_eq_severe_im_11988.jpg  nepal_eq_severe_im_35615.jpg
# nepal_eq_severe_im_11990.jpg  nepal_eq_severe_im_35618.jpg
# nepal_eq_severe_im_11994.jpg  nepal_eq_severe_im_35643.jpg
# nepal_eq_severe_im_12005.jpg  nepal_eq_severe_im_35644.jpg
# nepal_eq_severe_im_12006.jpg  nepal_eq_severe_im_35662.jpg
# nepal_eq_severe_im_12007.jpg  nepal_eq_severe_im_35664.jpg
# nepal_eq_severe_im_12009.jpg  nepal_eq_severe_im_35665.jpg
# nepal_eq_severe_im_12015.jpg  nepal_eq_severe_im_35666.jpg
# nepal_eq_severe_im_12017.jpg  nepal_eq_severe_im_35667.jpg
# nepal_eq_severe_im_12018.jpg  nepal_eq_severe_im_35676.jpg
# nepal_eq_severe_im_12019.jpg  nepal_eq_severe_im_35678.jpg
# nepal_eq_severe_im_12024.jpg  nepal_eq_severe_im_35680.jpg
# nepal_eq_severe_im_12028.jpg  nepal_eq_severe_im_35683.jpg
# nepal_eq_severe_im_12029.jpg  nepal_eq_severe_im_35685.jpg
# nepal_eq_severe_im_12037.jpg  nepal_eq_severe_im_35691.jpg
# nepal_eq_severe_im_12040.jpg  nepal_eq_severe_im_35698.jpg
# nepal_eq_severe_im_12042.jpg  nepal_eq_severe_im_35700.jpg
# nepal_eq_severe_im_12044.jpg  nepal_eq_severe_im_35708.jpg
# nepal_eq_severe_im_12053.jpg  nepal_eq_severe_im_35709.jpg
# nepal_eq_severe_im_12061.jpg  nepal_eq_severe_im_35715.jpg
# nepal_eq_severe_im_12065.jpg  nepal_eq_severe_im_35727.jpg
# nepal_eq_severe_im_12074.jpg  nepal_eq_severe_im_35751.jpg
# nepal_eq_severe_im_12075.jpg  nepal_eq_severe_im_35753.jpg
# nepal_eq_severe_im_12077.jpg  nepal_eq_severe_im_35757.jpg
# nepal_eq_severe_im_12090.jpg  nepal_eq_severe_im_35758.jpg
# nepal_eq_severe_im_12093.jpg  nepal_eq_severe_im_35805.jpg
# nepal_eq_severe_im_12094.jpg  nepal_eq_severe_im_35822.jpg
# nepal_eq_severe_im_12097.jpg  nepal_eq_severe_im_35830.jpg
# nepal_eq_severe_im_12098.jpg  nepal_eq_severe_im_35839.jpg
# nepal_eq_severe_im_120.jpg    nepal_eq_severe_im_35874.jpg
# nepal_eq_severe_im_12100.jpg  nepal_eq_severe_im_35877.jpg
# nepal_eq_severe_im_12101.jpg  nepal_eq_severe_im_35897.jpg
# nepal_eq_severe_im_12105.jpg  nepal_eq_severe_im_35902.jpg
# nepal_eq_severe_im_12106.jpg  nepal_eq_severe_im_35903.jpg
# nepal_eq_severe_im_12107.jpg  nepal_eq_severe_im_35904.jpg
# nepal_eq_severe_im_12109.jpg  nepal_eq_severe_im_35908.jpg
# nepal_eq_severe_im_12111.jpg  nepal_eq_severe_im_35912.jpg
# nepal_eq_severe_im_12112.jpg  nepal_eq_severe_im_35919.jpg
# nepal_eq_severe_im_12113.jpg  nepal_eq_severe_im_35929.jpg
# nepal_eq_severe_im_12117.jpg  nepal_eq_severe_im_35933.jpg
# nepal_eq_severe_im_12119.jpg  nepal_eq_severe_im_35938.jpg
# nepal_eq_severe_im_12121.jpg  nepal_eq_severe_im_35942.jpg
# nepal_eq_severe_im_12122.jpg  nepal_eq_severe_im_35950.jpg
# nepal_eq_severe_im_12123.jpg  nepal_eq_severe_im_35951.jpg
# nepal_eq_severe_im_12126.jpg  nepal_eq_severe_im_35952.jpg
# nepal_eq_severe_im_12129.jpg  nepal_eq_severe_im_35967.jpg
# nepal_eq_severe_im_12130.jpg  nepal_eq_severe_im_35970.jpg
# nepal_eq_severe_im_12133.jpg  nepal_eq_severe_im_35971.jpg
# nepal_eq_severe_im_12138.jpg  nepal_eq_severe_im_35975.jpg
# nepal_eq_severe_im_12139.jpg  nepal_eq_severe_im_35989.jpg
# nepal_eq_severe_im_12140.jpg  nepal_eq_severe_im_36009.jpg
# nepal_eq_severe_im_12141.jpg  nepal_eq_severe_im_36010.jpg
# nepal_eq_severe_im_12145.jpg  nepal_eq_severe_im_36015.jpg
# nepal_eq_severe_im_12148.jpg  nepal_eq_severe_im_36016.jpg
# nepal_eq_severe_im_12151.jpg  nepal_eq_severe_im_36019.jpg
# nepal_eq_severe_im_12154.jpg  nepal_eq_severe_im_36020.jpg
# nepal_eq_severe_im_12155.jpg  nepal_eq_severe_im_36022.jpg
# nepal_eq_severe_im_12157.jpg  nepal_eq_severe_im_36023.jpg
# nepal_eq_severe_im_12158.jpg  nepal_eq_severe_im_36027.jpg
# nepal_eq_severe_im_12160.jpg  nepal_eq_severe_im_36028.jpg
# nepal_eq_severe_im_12162.jpg  nepal_eq_severe_im_36030.jpg
# nepal_eq_severe_im_12166.jpg  nepal_eq_severe_im_36039.jpg
# nepal_eq_severe_im_12167.jpg  nepal_eq_severe_im_36045.jpg
# nepal_eq_severe_im_12168.jpg  nepal_eq_severe_im_36047.jpg
# nepal_eq_severe_im_12169.jpg  nepal_eq_severe_im_36054.jpg
# nepal_eq_severe_im_1216.jpg   nepal_eq_severe_im_36058.jpg
# nepal_eq_severe_im_12171.jpg  nepal_eq_severe_im_36059.jpg
# nepal_eq_severe_im_12175.jpg  nepal_eq_severe_im_36064.jpg
# nepal_eq_severe_im_12176.jpg  nepal_eq_severe_im_36067.jpg
# nepal_eq_severe_im_12177.jpg  nepal_eq_severe_im_36069.jpg
# nepal_eq_severe_im_12180.jpg  nepal_eq_severe_im_36070.jpg
# nepal_eq_severe_im_12183.jpg  nepal_eq_severe_im_36075.jpg
# nepal_eq_severe_im_12187.jpg  nepal_eq_severe_im_36078.jpg
# nepal_eq_severe_im_12192.jpg  nepal_eq_severe_im_36082.jpg
# nepal_eq_severe_im_12194.jpg  nepal_eq_severe_im_36092.jpg
# nepal_eq_severe_im_12198.jpg  nepal_eq_severe_im_36107.jpg
# nepal_eq_severe_im_12202.jpg  nepal_eq_severe_im_36133.jpg
# nepal_eq_severe_im_12206.jpg  nepal_eq_severe_im_36143.jpg
# nepal_eq_severe_im_12210.jpg  nepal_eq_severe_im_36148.jpg
# nepal_eq_severe_im_12211.jpg  nepal_eq_severe_im_36153.jpg
# nepal_eq_severe_im_12214.jpg  nepal_eq_severe_im_36159.jpg
# nepal_eq_severe_im_12224.jpg  nepal_eq_severe_im_3615.jpg
# nepal_eq_severe_im_12226.jpg  nepal_eq_severe_im_36160.jpg
# nepal_eq_severe_im_12227.jpg  nepal_eq_severe_im_36162.jpg
# nepal_eq_severe_im_12228.jpg  nepal_eq_severe_im_36166.jpg
# nepal_eq_severe_im_1222.jpg   nepal_eq_severe_im_36167.jpg
# nepal_eq_severe_im_12230.jpg  nepal_eq_severe_im_36170.jpg
# nepal_eq_severe_im_12233.jpg  nepal_eq_severe_im_36171.jpg
# nepal_eq_severe_im_12236.jpg  nepal_eq_severe_im_36190.jpg
# nepal_eq_severe_im_12239.jpg  nepal_eq_severe_im_36199.jpg
# nepal_eq_severe_im_12242.jpg  nepal_eq_severe_im_36200.jpg
# nepal_eq_severe_im_12251.jpg  nepal_eq_severe_im_36202.jpg
# nepal_eq_severe_im_1226.jpg   nepal_eq_severe_im_36204.jpg
# nepal_eq_severe_im_1228.jpg   nepal_eq_severe_im_36205.jpg
# nepal_eq_severe_im_122.jpg    nepal_eq_severe_im_36214.jpg
# nepal_eq_severe_im_1235.jpg   nepal_eq_severe_im_36215.jpg
# nepal_eq_severe_im_1240.jpg   nepal_eq_severe_im_36216.jpg
# nepal_eq_severe_im_12412.jpg  nepal_eq_severe_im_36217.jpg
# nepal_eq_severe_im_12413.jpg  nepal_eq_severe_im_36230.jpg
# nepal_eq_severe_im_12423.jpg  nepal_eq_severe_im_36234.jpg
# nepal_eq_severe_im_12424.jpg  nepal_eq_severe_im_36236.jpg
# nepal_eq_severe_im_12425.jpg  nepal_eq_severe_im_36240.jpg
# nepal_eq_severe_im_12439.jpg  nepal_eq_severe_im_36324.jpg
# nepal_eq_severe_im_12447.jpg  nepal_eq_severe_im_36333.jpg
# nepal_eq_severe_im_12448.jpg  nepal_eq_severe_im_36334.jpg
# nepal_eq_severe_im_12449.jpg  nepal_eq_severe_im_36336.jpg
# nepal_eq_severe_im_1244.jpg   nepal_eq_severe_im_36337.jpg
# nepal_eq_severe_im_12450.jpg  nepal_eq_severe_im_36338.jpg
# nepal_eq_severe_im_12451.jpg  nepal_eq_severe_im_36425.jpg
# nepal_eq_severe_im_12454.jpg  nepal_eq_severe_im_36433.jpg
# nepal_eq_severe_im_12455.jpg  nepal_eq_severe_im_36440.jpg
# nepal_eq_severe_im_12458.jpg  nepal_eq_severe_im_36441.jpg
# nepal_eq_severe_im_12459.jpg  nepal_eq_severe_im_36442.jpg
# nepal_eq_severe_im_12463.jpg  nepal_eq_severe_im_36443.jpg
# nepal_eq_severe_im_12464.jpg  nepal_eq_severe_im_36455.jpg
# nepal_eq_severe_im_12465.jpg  nepal_eq_severe_im_36456.jpg
# nepal_eq_severe_im_12468.jpg  nepal_eq_severe_im_36467.jpg
# nepal_eq_severe_im_12469.jpg  nepal_eq_severe_im_36468.jpg
# nepal_eq_severe_im_12471.jpg  nepal_eq_severe_im_36480.jpg
# nepal_eq_severe_im_12475.jpg  nepal_eq_severe_im_36482.jpg
# nepal_eq_severe_im_12478.jpg  nepal_eq_severe_im_36483.jpg
# nepal_eq_severe_im_12480.jpg  nepal_eq_severe_im_36485.jpg
# nepal_eq_severe_im_12482.jpg  nepal_eq_severe_im_36491.jpg
# nepal_eq_severe_im_12486.jpg  nepal_eq_severe_im_36500.jpg
# nepal_eq_severe_im_12487.jpg  nepal_eq_severe_im_36537.jpg
# nepal_eq_severe_im_12497.jpg  nepal_eq_severe_im_36540.jpg
# nepal_eq_severe_im_124.jpg    nepal_eq_severe_im_36544.jpg
# nepal_eq_severe_im_12501.jpg  nepal_eq_severe_im_36545.jpg
# nepal_eq_severe_im_12502.jpg  nepal_eq_severe_im_36551.jpg
# nepal_eq_severe_im_12504.jpg  nepal_eq_severe_im_36552.jpg
# nepal_eq_severe_im_12505.jpg  nepal_eq_severe_im_36558.jpg
# nepal_eq_severe_im_12506.jpg  nepal_eq_severe_im_36560.jpg
# nepal_eq_severe_im_12509.jpg  nepal_eq_severe_im_36561.jpg
# nepal_eq_severe_im_12514.jpg  nepal_eq_severe_im_36569.jpg
# nepal_eq_severe_im_12522.jpg  nepal_eq_severe_im_36580.jpg
# nepal_eq_severe_im_12532.jpg  nepal_eq_severe_im_36581.jpg
# nepal_eq_severe_im_12535.jpg  nepal_eq_severe_im_36583.jpg
# nepal_eq_severe_im_12536.jpg  nepal_eq_severe_im_36584.jpg
# nepal_eq_severe_im_12540.jpg  nepal_eq_severe_im_36585.jpg
# nepal_eq_severe_im_12544.jpg  nepal_eq_severe_im_36611.jpg
# nepal_eq_severe_im_12547.jpg  nepal_eq_severe_im_36637.jpg
# nepal_eq_severe_im_12551.jpg  nepal_eq_severe_im_36639.jpg
# nepal_eq_severe_im_12555.jpg  nepal_eq_severe_im_36641.jpg
# nepal_eq_severe_im_12558.jpg  nepal_eq_severe_im_36642.jpg
# nepal_eq_severe_im_12568.jpg  nepal_eq_severe_im_36644.jpg
# nepal_eq_severe_im_12573.jpg  nepal_eq_severe_im_36645.jpg
# nepal_eq_severe_im_13214.jpg  nepal_eq_severe_im_38098.jpg
# nepal_eq_severe_im_13217.jpg  nepal_eq_severe_im_38099.jpg
# nepal_eq_severe_im_13218.jpg  nepal_eq_severe_im_38102.jpg
# nepal_eq_severe_im_13220.jpg  nepal_eq_severe_im_38105.jpg
# nepal_eq_severe_im_13222.jpg  nepal_eq_severe_im_38120.jpg
# nepal_eq_severe_im_13224.jpg  nepal_eq_severe_im_38164.jpg
# nepal_eq_severe_im_13225.jpg  nepal_eq_severe_im_38184.jpg
# nepal_eq_severe_im_13228.jpg  nepal_eq_severe_im_38185.jpg
# nepal_eq_severe_im_13232.jpg  nepal_eq_severe_im_38186.jpg
# nepal_eq_severe_im_13241.jpg  nepal_eq_severe_im_38190.jpg
# nepal_eq_severe_im_13250.jpg  nepal_eq_severe_im_38191.jpg
# nepal_eq_severe_im_13251.jpg  nepal_eq_severe_im_38192.jpg
# nepal_eq_severe_im_13257.jpg  nepal_eq_severe_im_38197.jpg
# nepal_eq_severe_im_13258.jpg  nepal_eq_severe_im_38200.jpg
# nepal_eq_severe_im_13260.jpg  nepal_eq_severe_im_38204.jpg
# nepal_eq_severe_im_13261.jpg  nepal_eq_severe_im_38214.jpg
# nepal_eq_severe_im_13262.jpg  nepal_eq_severe_im_38232.jpg
# nepal_eq_severe_im_13266.jpg  nepal_eq_severe_im_38233.jpg
# nepal_eq_severe_im_13267.jpg  nepal_eq_severe_im_38240.jpg
# nepal_eq_severe_im_13268.jpg  nepal_eq_severe_im_38243.jpg
# nepal_eq_severe_im_13281.jpg  nepal_eq_severe_im_38246.jpg
# ...
# nepal_eq_severe_im_23109.jpg  nepal_eq_severe_im_9130.jpg
# nepal_eq_severe_im_23112.jpg  nepal_eq_severe_im_9132.jpg
# nepal_eq_severe_im_23113.jpg  nepal_eq_severe_im_9134.jpg
# nepal_eq_severe_im_23114.jpg  nepal_eq_severe_im_9136.jpg
# nepal_eq_severe_im_23115.jpg  nepal_eq_severe_im_9140.jpg
# nepal_eq_severe_im_23120.jpg  nepal_eq_severe_im_9143.jpg
# nepal_eq_severe_im_23123.jpg  nepal_eq_severe_im_9147.jpg
# nepal_eq_severe_im_23127.jpg  nepal_eq_severe_im_9149.jpg
# nepal_eq_severe_im_23129.jpg  nepal_eq_severe_im_9158.jpg
# nepal_eq_severe_im_23132.jpg  nepal_eq_severe_im_9161.jpg
# nepal_eq_severe_im_23133.jpg  nepal_eq_severe_im_9163.jpg
# nepal_eq_severe_im_23134.jpg  nepal_eq_severe_im_9164.jpg
# nepal_eq_severe_im_23137.jpg  nepal_eq_severe_im_9167.jpg
# nepal_eq_severe_im_23148.jpg  nepal_eq_severe_im_9168.jpg
# nepal_eq_severe_im_23150.jpg  nepal_eq_severe_im_9171.jpg
# nepal_eq_severe_im_23151.jpg  nepal_eq_severe_im_9173.jpg
# nepal_eq_severe_im_23152.jpg  nepal_eq_severe_im_9176.jpg
# nepal_eq_severe_im_23153.jpg  nepal_eq_severe_im_9183.jpg
# nepal_eq_severe_im_23305.jpg  nepal_eq_severe_im_9366.jpg
# nepal_eq_severe_im_23375.jpg  nepal_eq_severe_im_9368.jpg
# nepal_eq_severe_im_23382.jpg  nepal_eq_severe_im_9369.jpg
# nepal_eq_severe_im_23384.jpg  nepal_eq_severe_im_936.jpg
# nepal_eq_severe_im_23385.jpg  nepal_eq_severe_im_9372.jpg
# nepal_eq_severe_im_23386.jpg  nepal_eq_severe_im_9373.jpg
# nepal_eq_severe_im_23388.jpg  nepal_eq_severe_im_9375.jpg
# nepal_eq_severe_im_23393.jpg  nepal_eq_severe_im_9376.jpg
# nepal_eq_severe_im_23394.jpg  nepal_eq_severe_im_9377.jpg
# nepal_eq_severe_im_23400.jpg  nepal_eq_severe_im_9379.jpg
# nepal_eq_severe_im_23401.jpg  nepal_eq_severe_im_937.jpg
# nepal_eq_severe_im_23404.jpg  nepal_eq_severe_im_9380.jpg
# nepal_eq_severe_im_23407.jpg  nepal_eq_severe_im_9383.jpg
# nepal_eq_severe_im_23409.jpg  nepal_eq_severe_im_9385.jpg
# nepal_eq_severe_im_23410.jpg  nepal_eq_severe_im_9389.jpg
# nepal_eq_severe_im_23412.jpg  nepal_eq_severe_im_9390.jpg
# nepal_eq_severe_im_23413.jpg  nepal_eq_severe_im_9391.jpg
# nepal_eq_severe_im_23416.jpg  nepal_eq_severe_im_9396.jpg
# nepal_eq_severe_im_23417.jpg  nepal_eq_severe_im_9397.jpg
# nepal_eq_severe_im_23426.jpg  nepal_eq_severe_im_9399.jpg
# nepal_eq_severe_im_23428.jpg  nepal_eq_severe_im_939.jpg
# nepal_eq_severe_im_23433.jpg  nepal_eq_severe_im_9404.jpg
# nepal_eq_severe_im_23442.jpg  nepal_eq_severe_im_9405.jpg
# nepal_eq_severe_im_23479.jpg  nepal_eq_severe_im_9407.jpg
# nepal_eq_severe_im_23481.jpg  nepal_eq_severe_im_9413.jpg
# nepal_eq_severe_im_23483.jpg  nepal_eq_severe_im_9418.jpg
# nepal_eq_severe_im_23487.jpg  nepal_eq_severe_im_9419.jpg
# nepal_eq_severe_im_23490.jpg  nepal_eq_severe_im_9420.jpg
# nepal_eq_severe_im_23491.jpg  nepal_eq_severe_im_9423.jpg
# nepal_eq_severe_im_23492.jpg  nepal_eq_severe_im_9426.jpg
# nepal_eq_severe_im_23496.jpg  nepal_eq_severe_im_942.jpg
# nepal_eq_severe_im_23505.jpg  nepal_eq_severe_im_9432.jpg
# nepal_eq_severe_im_23506.jpg  nepal_eq_severe_im_943.jpg
# nepal_eq_severe_im_23509.jpg  nepal_eq_severe_im_9441.jpg
# nepal_eq_severe_im_23511.jpg  nepal_eq_severe_im_9444.jpg
# nepal_eq_severe_im_23555.jpg  nepal_eq_severe_im_9445.jpg
# nepal_eq_severe_im_23556.jpg  nepal_eq_severe_im_9446.jpg
# nepal_eq_severe_im_23559.jpg  nepal_eq_severe_im_9448.jpg
# nepal_eq_severe_im_23560.jpg  nepal_eq_severe_im_9449.jpg
# nepal_eq_severe_im_23562.jpg  nepal_eq_severe_im_9450.jpg
# nepal_eq_severe_im_23563.jpg  nepal_eq_severe_im_9453.jpg
# nepal_eq_severe_im_23565.jpg  nepal_eq_severe_im_9454.jpg
# nepal_eq_severe_im_23566.jpg  nepal_eq_severe_im_9456.jpg
# nepal_eq_severe_im_23571.jpg  nepal_eq_severe_im_9457.jpg
# nepal_eq_severe_im_23572.jpg  nepal_eq_severe_im_9459.jpg
# nepal_eq_severe_im_23573.jpg  nepal_eq_severe_im_945.jpg
# nepal_eq_severe_im_23574.jpg  nepal_eq_severe_im_9460.jpg
# nepal_eq_severe_im_23576.jpg  nepal_eq_severe_im_9461.jpg
# nepal_eq_severe_im_23577.jpg  nepal_eq_severe_im_9462.jpg
# nepal_eq_severe_im_23582.jpg  nepal_eq_severe_im_9463.jpg
# nepal_eq_severe_im_23585.jpg  nepal_eq_severe_im_9466.jpg
# nepal_eq_severe_im_23587.jpg  nepal_eq_severe_im_9469.jpg
# nepal_eq_severe_im_23607.jpg  nepal_eq_severe_im_9471.jpg
# nepal_eq_severe_im_23612.jpg  nepal_eq_severe_im_9474.jpg
# nepal_eq_severe_im_23613.jpg  nepal_eq_severe_im_9478.jpg
# nepal_eq_severe_im_23614.jpg  nepal_eq_severe_im_9481.jpg
# nepal_eq_severe_im_23634.jpg  nepal_eq_severe_im_9543.jpg
# nepal_eq_severe_im_23636.jpg  nepal_eq_severe_im_9544.jpg
# nepal_eq_severe_im_23637.jpg  nepal_eq_severe_im_9546.jpg
# nepal_eq_severe_im_23638.jpg  nepal_eq_severe_im_9547.jpg
# nepal_eq_severe_im_23639.jpg  nepal_eq_severe_im_9548.jpg
# nepal_eq_severe_im_23644.jpg  nepal_eq_severe_im_9549.jpg
# nepal_eq_severe_im_23655.jpg  nepal_eq_severe_im_9550.jpg
# nepal_eq_severe_im_23674.jpg  nepal_eq_severe_im_9551.jpg
# nepal_eq_severe_im_23688.jpg  nepal_eq_severe_im_9553.jpg
# nepal_eq_severe_im_23697.jpg  nepal_eq_severe_im_9554.jpg
# nepal_eq_severe_im_23700.jpg  nepal_eq_severe_im_9555.jpg
# nepal_eq_severe_im_23702.jpg  nepal_eq_severe_im_9557.jpg
# nepal_eq_severe_im_23707.jpg  nepal_eq_severe_im_9559.jpg
# nepal_eq_severe_im_23724.jpg  nepal_eq_severe_im_9560.jpg
# nepal_eq_severe_im_23739.jpg  nepal_eq_severe_im_9563.jpg
# nepal_eq_severe_im_23740.jpg  nepal_eq_severe_im_9565.jpg
# nepal_eq_severe_im_23746.jpg  nepal_eq_severe_im_9566.jpg
# nepal_eq_severe_im_23757.jpg  nepal_eq_severe_im_9569.jpg
# nepal_eq_severe_im_23763.jpg  nepal_eq_severe_im_9571.jpg
# nepal_eq_severe_im_23765.jpg  nepal_eq_severe_im_9575.jpg
# nepal_eq_severe_im_23785.jpg  nepal_eq_severe_im_9576.jpg
# nepal_eq_severe_im_23786.jpg  nepal_eq_severe_im_9577.jpg
# nepal_eq_severe_im_23792.jpg  nepal_eq_severe_im_9579.jpg
# nepal_eq_severe_im_23803.jpg  nepal_eq_severe_im_9580.jpg
# nepal_eq_severe_im_23806.jpg  nepal_eq_severe_im_9582.jpg
# nepal_eq_severe_im_23810.jpg  nepal_eq_severe_im_9583.jpg
# nepal_eq_severe_im_23811.jpg  nepal_eq_severe_im_9584.jpg
# nepal_eq_severe_im_23812.jpg  nepal_eq_severe_im_9586.jpg
# nepal_eq_severe_im_23813.jpg  nepal_eq_severe_im_9588.jpg
# nepal_eq_severe_im_23816.jpg  nepal_eq_severe_im_958.jpg
# nepal_eq_severe_im_23817.jpg  nepal_eq_severe_im_9590.jpg
# nepal_eq_severe_im_23818.jpg  nepal_eq_severe_im_9594.jpg
# nepal_eq_severe_im_23819.jpg  nepal_eq_severe_im_9595.jpg
# nepal_eq_severe_im_23821.jpg  nepal_eq_severe_im_9598.jpg
# nepal_eq_severe_im_23822.jpg  nepal_eq_severe_im_9602.jpg
# nepal_eq_severe_im_23824.jpg  nepal_eq_severe_im_9606.jpg
# nepal_eq_severe_im_23825.jpg  nepal_eq_severe_im_9608.jpg
# nepal_eq_severe_im_23829.jpg  nepal_eq_severe_im_9612.jpg
# nepal_eq_severe_im_23867.jpg  nepal_eq_severe_im_9616.jpg
# nepal_eq_severe_im_23869.jpg  nepal_eq_severe_im_961.jpg
# nepal_eq_severe_im_23870.jpg  nepal_eq_severe_im_9625.jpg
# nepal_eq_severe_im_23871.jpg  nepal_eq_severe_im_9628.jpg
# nepal_eq_severe_im_23873.jpg  nepal_eq_severe_im_9629.jpg
# nepal_eq_severe_im_23874.jpg  nepal_eq_severe_im_9630.jpg
# nepal_eq_severe_im_23876.jpg  nepal_eq_severe_im_9631.jpg
# nepal_eq_severe_im_23878.jpg  nepal_eq_severe_im_9632.jpg
# nepal_eq_severe_im_23886.jpg  nepal_eq_severe_im_9633.jpg
# nepal_eq_severe_im_23888.jpg  nepal_eq_severe_im_963.jpg
# nepal_eq_severe_im_23889.jpg  nepal_eq_severe_im_9642.jpg
# nepal_eq_severe_im_23891.jpg  nepal_eq_severe_im_9643.jpg
# nepal_eq_severe_im_23892.jpg  nepal_eq_severe_im_9644.jpg
# nepal_eq_severe_im_23894.jpg  nepal_eq_severe_im_9645.jpg
# nepal_eq_severe_im_23896.jpg  nepal_eq_severe_im_9646.jpg
# nepal_eq_severe_im_23898.jpg  nepal_eq_severe_im_964.jpg
# nepal_eq_severe_im_23899.jpg  nepal_eq_severe_im_9651.jpg
# nepal_eq_severe_im_23900.jpg  nepal_eq_severe_im_9658.jpg
# nepal_eq_severe_im_23902.jpg  nepal_eq_severe_im_9661.jpg
# nepal_eq_severe_im_23906.jpg  nepal_eq_severe_im_9664.jpg
# nepal_eq_severe_im_24031.jpg  nepal_eq_severe_im_9668.jpg
# nepal_eq_severe_im_24032.jpg  nepal_eq_severe_im_966.jpg
# nepal_eq_severe_im_24033.jpg  nepal_eq_severe_im_9670.jpg
# nepal_eq_severe_im_24034.jpg  nepal_eq_severe_im_9673.jpg
# nepal_eq_severe_im_24035.jpg  nepal_eq_severe_im_967.jpg
# nepal_eq_severe_im_24036.jpg  nepal_eq_severe_im_9682.jpg
# nepal_eq_severe_im_24037.jpg  nepal_eq_severe_im_9683.jpg
# nepal_eq_severe_im_24038.jpg  nepal_eq_severe_im_9685.jpg
# nepal_eq_severe_im_24043.jpg  nepal_eq_severe_im_9691.jpg
# nepal_eq_severe_im_24044.jpg  nepal_eq_severe_im_969.jpg
# nepal_eq_severe_im_24045.jpg  nepal_eq_severe_im_9714.jpg
# nepal_eq_severe_im_24046.jpg  nepal_eq_severe_im_9715.jpg
# nepal_eq_severe_im_24048.jpg  nepal_eq_severe_im_9716.jpg
# nepal_eq_severe_im_24050.jpg  nepal_eq_severe_im_9718.jpg
# nepal_eq_severe_im_24056.jpg  nepal_eq_severe_im_9722.jpg
# nepal_eq_severe_im_24057.jpg  nepal_eq_severe_im_9725.jpg
# nepal_eq_severe_im_24058.jpg  nepal_eq_severe_im_9726.jpg
# nepal_eq_severe_im_24072.jpg  nepal_eq_severe_im_9727.jpg
# nepal_eq_severe_im_24073.jpg  nepal_eq_severe_im_9728.jpg
# nepal_eq_severe_im_24078.jpg  nepal_eq_severe_im_9730.jpg
# nepal_eq_severe_im_24080.jpg  nepal_eq_severe_im_9734.jpg
# nepal_eq_severe_im_24082.jpg  nepal_eq_severe_im_973.jpg
# nepal_eq_severe_im_24085.jpg  nepal_eq_severe_im_9741.jpg
# nepal_eq_severe_im_24091.jpg  nepal_eq_severe_im_9742.jpg
# nepal_eq_severe_im_24098.jpg  nepal_eq_severe_im_9747.jpg
# nepal_eq_severe_im_24100.jpg  nepal_eq_severe_im_9749.jpg
# nepal_eq_severe_im_24101.jpg  nepal_eq_severe_im_9751.jpg
# nepal_eq_severe_im_24145.jpg  nepal_eq_severe_im_9757.jpg
# nepal_eq_severe_im_24146.jpg  nepal_eq_severe_im_9758.jpg
# nepal_eq_severe_im_24184.jpg  nepal_eq_severe_im_975.jpg
# nepal_eq_severe_im_24193.jpg  nepal_eq_severe_im_9760.jpg
# nepal_eq_severe_im_24194.jpg  nepal_eq_severe_im_9763.jpg
# nepal_eq_severe_im_24197.jpg  nepal_eq_severe_im_9766.jpg
# nepal_eq_severe_im_24202.jpg  nepal_eq_severe_im_9768.jpg
# nepal_eq_severe_im_24204.jpg  nepal_eq_severe_im_9771.jpg
# nepal_eq_severe_im_24207.jpg  nepal_eq_severe_im_9776.jpg
# nepal_eq_severe_im_24208.jpg  nepal_eq_severe_im_9780.jpg
# nepal_eq_severe_im_24209.jpg  nepal_eq_severe_im_978.jpg
# nepal_eq_severe_im_24210.jpg  nepal_eq_severe_im_9791.jpg
# nepal_eq_severe_im_24212.jpg  nepal_eq_severe_im_9793.jpg
# nepal_eq_severe_im_24214.jpg  nepal_eq_severe_im_9795.jpg
# nepal_eq_severe_im_24215.jpg  nepal_eq_severe_im_9797.jpg
# nepal_eq_severe_im_24232.jpg  nepal_eq_severe_im_9800.jpg
# nepal_eq_severe_im_24258.jpg  nepal_eq_severe_im_9801.jpg
# nepal_eq_severe_im_24259.jpg  nepal_eq_severe_im_9803.jpg
# nepal_eq_severe_im_24260.jpg  nepal_eq_severe_im_980.jpg
# nepal_eq_severe_im_24262.jpg  nepal_eq_severe_im_9812.jpg
# nepal_eq_severe_im_24263.jpg  nepal_eq_severe_im_9814.jpg
# nepal_eq_severe_im_24265.jpg  nepal_eq_severe_im_9815.jpg
# nepal_eq_severe_im_24266.jpg  nepal_eq_severe_im_9816.jpg
# nepal_eq_severe_im_24267.jpg  nepal_eq_severe_im_9817.jpg
# nepal_eq_severe_im_24308.jpg  nepal_eq_severe_im_9818.jpg
# nepal_eq_severe_im_24374.jpg  nepal_eq_severe_im_9821.jpg
# nepal_eq_severe_im_24414.jpg  nepal_eq_severe_im_9823.jpg
# nepal_eq_severe_im_24424.jpg  nepal_eq_severe_im_982.jpg
# nepal_eq_severe_im_24438.jpg  nepal_eq_severe_im_984.jpg
# nepal_eq_severe_im_24445.jpg  nepal_eq_severe_im_9864.jpg
# nepal_eq_severe_im_24448.jpg  nepal_eq_severe_im_9868.jpg
# nepal_eq_severe_im_24450.jpg  nepal_eq_severe_im_9880.jpg
# nepal_eq_severe_im_24451.jpg  nepal_eq_severe_im_9881.jpg
# nepal_eq_severe_im_24453.jpg  nepal_eq_severe_im_9882.jpg
# nepal_eq_severe_im_24454.jpg  nepal_eq_severe_im_9883.jpg
# nepal_eq_severe_im_24455.jpg  nepal_eq_severe_im_9884.jpg
# nepal_eq_severe_im_24456.jpg  nepal_eq_severe_im_9885.jpg
# nepal_eq_severe_im_24459.jpg  nepal_eq_severe_im_9890.jpg
# nepal_eq_severe_im_24461.jpg  nepal_eq_severe_im_9891.jpg
# nepal_eq_severe_im_24462.jpg  nepal_eq_severe_im_9894.jpg
# nepal_eq_severe_im_24463.jpg  nepal_eq_severe_im_9895.jpg
# nepal_eq_severe_im_24464.jpg  nepal_eq_severe_im_9896.jpg
# nepal_eq_severe_im_24467.jpg  nepal_eq_severe_im_9897.jpg
# nepal_eq_severe_im_24469.jpg  nepal_eq_severe_im_9904.jpg
# nepal_eq_severe_im_24472.jpg  nepal_eq_severe_im_9906.jpg
# nepal_eq_severe_im_24526.jpg  nepal_eq_severe_im_9908.jpg
# nepal_eq_severe_im_24532.jpg  nepal_eq_severe_im_990.jpg
# nepal_eq_severe_im_24564.jpg  nepal_eq_severe_im_9916.jpg
# nepal_eq_severe_im_24584.jpg  nepal_eq_severe_im_9917.jpg
# nepal_eq_severe_im_24588.jpg  nepal_eq_severe_im_9918.jpg
# nepal_eq_severe_im_245.jpg    nepal_eq_severe_im_9919.jpg
# nepal_eq_severe_im_24608.jpg  nepal_eq_severe_im_991.jpg
# nepal_eq_severe_im_24669.jpg  nepal_eq_severe_im_9920.jpg
# nepal_eq_severe_im_24676.jpg  nepal_eq_severe_im_9921.jpg
# nepal_eq_severe_im_24677.jpg  nepal_eq_severe_im_9922.jpg
# nepal_eq_severe_im_24680.jpg  nepal_eq_severe_im_9924.jpg
# nepal_eq_severe_im_24681.jpg  nepal_eq_severe_im_9925.jpg
# nepal_eq_severe_im_24682.jpg  nepal_eq_severe_im_9926.jpg
# nepal_eq_severe_im_24683.jpg  nepal_eq_severe_im_9927.jpg
# nepal_eq_severe_im_24684.jpg  nepal_eq_severe_im_9928.jpg
# nepal_eq_severe_im_24685.jpg  nepal_eq_severe_im_9929.jpg
# nepal_eq_severe_im_24686.jpg  nepal_eq_severe_im_992.jpg
# nepal_eq_severe_im_24687.jpg  nepal_eq_severe_im_993.jpg
# nepal_eq_severe_im_24688.jpg  nepal_eq_severe_im_9945.jpg
# nepal_eq_severe_im_24689.jpg  nepal_eq_severe_im_994.jpg
# nepal_eq_severe_im_24693.jpg  nepal_eq_severe_im_9950.jpg
# nepal_eq_severe_im_24694.jpg  nepal_eq_severe_im_9953.jpg
# nepal_eq_severe_im_246.jpg    nepal_eq_severe_im_9958.jpg
# nepal_eq_severe_im_24731.jpg  nepal_eq_severe_im_995.jpg
# nepal_eq_severe_im_24739.jpg  nepal_eq_severe_im_9962.jpg
# nepal_eq_severe_im_24742.jpg  nepal_eq_severe_im_997.jpg
# nepal_eq_severe_im_24745.jpg  nepal_eq_severe_im_9981.jpg
# nepal_eq_severe_im_24746.jpg  nepal_eq_severe_im_9982.jpg
# nepal_eq_severe_im_24751.jpg  nepal_eq_severe_im_9983.jpg
# nepal_eq_severe_im_24753.jpg  nepal_eq_severe_im_9986.jpg
# nepal_eq_severe_im_24755.jpg  nepal_eq_severe_im_999.jpg
# nepal_eq_severe_im_24757.jpg  nepal_eq_severe_im_99.jpg
# nepal_eq_severe_im_24762.jpg  nepal_eq_severe_im_9.jpg

# %%
ficheros = glob("./seg_train/mild/*")
ficheros[1]
# Out:
# './seg_train/mild/nepal_eq_mild_im_6724.jpg'

# %%
imagen = load_img(ficheros[1])
imagen
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=786x500 at 0x7FCAFB8C3860>

# %%
imagen.size
# Out:
# (786, 500)

# %%
train_data_dir = 'seg_train'
validation_data_dir = 'seg_test'
test_data_dir = 'seg_test'

batch_size = 16

# %% [markdown]
# Para ver opciones:
#
# https://keras.io/api/preprocessing/image/#imagedatagenerator-class

# %%
# data augmentation:

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    fill_mode='nearest',
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True)

# %%
imagen_num = np.array([img_to_array(imagen)])

# %%
plt.imshow(train_datagen.flow(imagen_num)[0][0])
plt.axis("off");

# %% [markdown]
# ## **Red base**

# %% [markdown]
# https://keras.io/api/applications/
#
# http://josephpcohen.com/w/visualizing-cnn-architectures-side-by-side-with-mxnet/

# %%
# dimensiones a las que vamos a llevar las imágenes
img_width, img_height = 150, 150

normed_dims = (img_height, img_width)

# %%
normed_dims
# Out:
# (150, 150)

# %%
#from keras.applications.inception_v3 import InceptionV3
#base_model = InceptionV3(weights='imagenet', include_top=False)
#preprocess_input = lambda x:x/255.

# %%
# tf.keras.applications.VGG19(
#     include_top=True,
#     weights="imagenet",
#     input_tensor=None,
#     input_shape=None,
#     pooling=None,
#     classes=1000,
#     classifier_activation="softmax",
# )

# %%
from keras.applications.resnet50 import preprocess_input
from keras.applications.resnet50 import ResNet50
base_model = ResNet50(include_top=False, input_shape=normed_dims + (3,))
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# /tensorflow-1.15.2/python3.6/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 3s 0us/step

# %%
# from keras.applications.mobilenet_v2 import preprocess_input
# from keras.applications.mobilenet_v2 import MobileNetV2
# base_model = MobileNetV2(include_top=False, input_shape=normed_dims + (3,))

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
len(base_model.layers)
# Out:
# 175

# %%
#base_model.summary()

# %%
# sparse_categorical_crossentropy

#building: 0
# 1,0,0,0,0,0

# forest': 1
# 0,1,0,0,0,0

# glacier: 2
# 0,0,1,0,0,0

# mountain: 3
# 0,0,0,1,0,0

# sea: 4,
# 0,0,0,0,1,0

# street: 5
# 0,0,0,0,0,1

# %%
# capas que añado:

aux = base_model.output
aux = GlobalAveragePooling2D()(aux)
#aux = Flatten(input_shape = (2048,))(aux)
aux = Dense(9, activation='relu',
            #kernel_regularizer=regularizers.l2(0.01) # 0.1, 0.01, 0.001
            )(aux)
aux = Dense(3, activation="softmax")(aux)
model = Model(input=base_model.input, output=aux)

model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy',
              metrics=["acc"])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   # Remove the CWD from sys.path while we load stuff.

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 150, 150, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 156, 156, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 75, 75, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 75, 75, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 75, 75, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 77, 77, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 38, 38, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 38, 38, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 38, 38, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 38, 38, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 38, 38, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 38, 38, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 38, 38, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 38, 38, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 38, 38, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 38, 38, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 38, 38, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 38, 38, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 38, 38, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 38, 38, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 38, 38, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 38, 38, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 38, 38, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 38, 38, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 38, 38, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 38, 38, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 38, 38, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 38, 38, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 38, 38, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 38, 38, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 38, 38, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 38, 38, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 38, 38, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 38, 38, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 38, 38, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 38, 38, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 38, 38, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 38, 38, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 38, 38, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 19, 19, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 19, 19, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 19, 19, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 19, 19, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 19, 19, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 19, 19, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 19, 19, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 19, 19, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 19, 19, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 19, 19, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 19, 19, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 19, 19, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 19, 19, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 19, 19, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 19, 19, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 19, 19, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 19, 19, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 19, 19, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 19, 19, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 19, 19, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 19, 19, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 19, 19, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 19, 19, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 19, 19, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 19, 19, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 19, 19, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 19, 19, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 19, 19, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 19, 19, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 19, 19, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 19, 19, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 19, 19, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 19, 19, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 19, 19, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 19, 19, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 19, 19, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 19, 19, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 19, 19, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 10, 10, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 10, 10, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 10, 10, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 10, 10, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 10, 10, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 10, 10, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 10, 10, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 10, 10, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 10, 10, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 10, 10, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 10, 10, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 10, 10, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 10, 10, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 10, 10, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 10, 10, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 10, 10, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 10, 10, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 10, 10, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 10, 10, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 10, 10, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 10, 10, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 10, 10, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 10, 10, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 10, 10, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 10, 10, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 10, 10, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 10, 10, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 10, 10, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 10, 10, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 10, 10, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 10, 10, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 10, 10, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 10, 10, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 10, 10, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 10, 10, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 10, 10, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 10, 10, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 10, 10, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 10, 10, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 10, 10, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 10, 10, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 10, 10, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 10, 10, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 10, 10, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 10, 10, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 10, 10, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 10, 10, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 10, 10, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 10, 10, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 10, 10, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 10, 10, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 10, 10, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 10, 10, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 10, 10, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 10, 10, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 10, 10, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 10, 10, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 10, 10, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 10, 10, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 10, 10, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 10, 10, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 5, 5, 512)    524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 5, 5, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 5, 5, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 5, 5, 512)    2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 5, 5, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 5, 5, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 5, 5, 2048)   1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 5, 5, 2048)   2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 5, 5, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 5, 5, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 5, 5, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 5, 5, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 5, 5, 512)    1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 5, 5, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 5, 5, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 5, 5, 512)    2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 5, 5, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 5, 5, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 5, 5, 2048)   1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 5, 5, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 5, 5, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 5, 5, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 5, 5, 512)    1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 5, 5, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 5, 5, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 5, 5, 512)    2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 5, 5, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 5, 5, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 5, 5, 2048)   1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 5, 5, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 5, 5, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 5, 5, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           activation_49[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 9)            18441       global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 3)            30          dense_1[0][0]
# ==================================================================================================
# Total params: 23,606,183
# Trainable params: 18,471
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

#if COLAB:
#    display(SVG(model_to_dot(model, show_shapes=True,dpi=72).create(prog='dot', format='svg')))
#else:
#    display(SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg')))

# %%
train_datagen = ImageDataGenerator(
    dtype='float32',
    preprocessing_function = preprocess_input,
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    fill_mode='nearest',
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

val_datagen  = ImageDataGenerator(dtype='float32',
                                  preprocessing_function = preprocess_input)

test_datagen = ImageDataGenerator(dtype='float32',
                                  preprocessing_function = preprocess_input)

# %%
validation_data_dir, normed_dims
# Out:
# ('seg_test', (150, 150))

# %%
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=normed_dims,
    batch_size=batch_size,
    shuffle=True,
    class_mode='sparse')

validation_generator = val_datagen.flow_from_directory(
    validation_data_dir,
    target_size=normed_dims,
    batch_size=batch_size,
    shuffle=False,
    class_mode='sparse')

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=normed_dims,
    batch_size=batch_size,
    shuffle=False,
    class_mode='sparse')
# Out:
# Found 8953 images belonging to 3 classes.
# Found 2079 images belonging to 3 classes.
# Found 2079 images belonging to 3 classes.

# %%
train_generator.class_indices
# Out:
# {'mild': 0, 'none': 1, 'severe': 2}

# %%
number_train_samples = train_generator.n
number_val_samples   = validation_generator.n
number_test_samples  = test_generator.n

number_train_samples, number_val_samples, number_test_samples
# Out:
# (8953, 2079, 2079)

# %%
from matplotlib.ticker import MaxNLocator

def grafica_entrenamiento(tr_acc, val_acc, tr_loss, val_loss, best_i,
                          figsize=(10,4)):
    plt.figure(figsize=figsize)
    ax = plt.subplot(1,2,1)
    plt.plot(1+np.arange(len(tr_acc)),  100*np.array(tr_acc))
    plt.plot(1+np.arange(len(val_acc)), 100*np.array(val_acc))
    plt.plot(1+best_i, 100*val_acc[best_i], 'or')
    plt.title('tasa de acierto del modelo (%)', fontsize=18)
    plt.ylabel('tasa de acierto (%)', fontsize=18)
    plt.xlabel('época', fontsize=18)
    plt.legend(['entrenamiento', 'validación'], loc='upper left')
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))

    plt.subplot(1,2,2)
    plt.plot(1+np.arange(len(tr_acc)), np.array(tr_loss))
    plt.plot(1+np.arange(len(val_acc)), np.array(val_loss))
    plt.plot(1+best_i, val_loss[best_i], 'or')
    plt.title('loss del modelo', fontsize=18)
    plt.ylabel('loss', fontsize=18)
    plt.xlabel('época', fontsize=18)
    plt.legend(['entrenamiento', 'validación'], loc='upper left')
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    plt.show()

# %%
acum_tr_acc = []
acum_val_acc = []
best_val_acc = -1000
acum_tr_loss  = []
acum_val_loss = []

# %%
epochs = 30

modelpath="model_current_best_parte3.h5"

checkpoint = ModelCheckpoint(modelpath, monitor='val_acc', verbose=1,
                              save_best_only=True,
                              mode='max') # graba sólo los que mejoran en validación
callbacks_list = [checkpoint]
for e in range(epochs):
    history = model.fit_generator(generator = train_generator, 
                                  steps_per_epoch=number_train_samples // batch_size,
                                  epochs=1,
                                  callbacks=callbacks_list,
                                  verbose=1,
                                  shuffle = True,
                                  validation_data=validation_generator,
                                  validation_steps=number_val_samples // batch_size
                                  )
    
    if history.history['val_acc'][-1] > best_val_acc:
        print("Validation accuracy improved from",
            best_val_acc, 'to', history.history['val_acc'])
        print("saving weights")
        best_val_acc = history.history['val_acc'][-1]
    
    acum_tr_acc.append(history.history['acc'][0])
    acum_val_acc.append(history.history['val_acc'][0])
    acum_tr_loss.append(history.history['loss'][0])
    acum_val_loss.append(history.history['val_loss'][0])
    
    if len(acum_tr_acc) > 1:
        clear_output()
        best_i = np.argmax(acum_val_acc)
        grafica_entrenamiento(acum_tr_acc, acum_val_acc, acum_tr_loss, acum_val_loss, best_i)

# %%
model = load_model(modelpath)

# %% [markdown]
# ## **Resultados obtenidos**

# %%
scores_tr = model.evaluate(train_generator)
print('Train loss    :', scores_tr[0])
print('Train accuracy:', scores_tr[1])
print()

scores_val = model.evaluate(validation_generator)
print('Val loss    :', scores_val[0])
print('Val accuracy:', scores_val[1])
print()

scores_te = model.evaluate(test_generator)
print('Test loss     :', scores_te[0])
print('Test accuracy :', scores_te[1])
# Out:
# 253/560 [============>.................] - ETA: 1:11
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# 560/560 [==============================] - 130s 232ms/step
# Train loss    : 2.108485698699951
# Train accuracy: 0.7676756381988525
#
# 130/130 [==============================] - 22s 167ms/step
# Val loss    : 0.11696960777044296
# Val accuracy: 0.7484367489814758
#
# 130/130 [==============================] - 22s 165ms/step
# Test loss     : 0.11696960777044296
# Test accuracy : 0.7484367489814758

# %%
y_real = test_generator.classes
y_pred_proba = model.predict_generator(test_generator)

# %%
y_real[:5]
# Out:
# array([0, 0, 0, 0, 0], dtype=int32)

# %%
y_pred_proba[:5]
# Out:
# array([[1.56479931e-04, 9.53055917e-07, 9.99842525e-01],
#        [3.57680142e-01, 2.10271757e-02, 6.21292651e-01],
#        [1.07495025e-01, 4.13629832e-03, 8.88368726e-01],
#        [2.10384931e-02, 2.96913902e-04, 9.78664577e-01],
#        [2.70526037e-02, 5.38264358e-05, 9.72893536e-01]], dtype=float32)

# %%
test_generator.class_indices
# Out:
# {'mild': 0, 'none': 1, 'severe': 2}

# %%
num2class = {test_generator.class_indices[x]:x  for x in test_generator.class_indices.keys()}
num2class
# Out:
# {0: 'mild', 1: 'none', 2: 'severe'}

# %%
for clase in range(3):
    nombre_clase = num2class[clase]

    fpr, tpr, thresholds = roc_curve(y_real==clase, y_pred_proba[:,clase])
    fig, ax1 = plt.subplots(1,1)
    ax1.plot(fpr, tpr, 'r-.', label = 'CNN (%2.2f)' % auc(fpr, tpr))
    ax1.set_xlabel('False Positive Rate')
    ax1.set_ylabel('True Positive Rate')
    ax1.plot(fpr, fpr, 'b-', label = 'Random Guess')
    ax1.set_title(nombre_clase)
    ax1.legend()
    plt.show()

# %% [markdown]
# ## **Visualización de ejemplos de test**

# %%
test_datagen2 = ImageDataGenerator(dtype='float32')

test_generator2 = test_datagen2.flow_from_directory(
    test_data_dir,
    target_size=normed_dims,
    batch_size=test_generator.n,
    shuffle=False,
    class_mode='sparse')
# Out:
# Found 2079 images belonging to 3 classes.

# %%
test_generator2.reset()
X_te, y_te = test_generator2.next()

# %%
test_generator2.class_indices
# Out:
# {'mild': 0, 'none': 1, 'severe': 2}

# %%
y_te
# Out:
# array([0., 0., 0., ..., 2., 2., 2.], dtype=float32)

# %%
ind_te1 = 1

image = X_te[ind_te1].copy()

print("Clase real:", num2class[y_te[ind_te1]])
plt.imshow(image/255, cmap='jet')
plt.axis("off")
p = model.predict(preprocess_input(np.array([image])))[0]
cadena = ""
for i in range(len(num2class)):
    cadena = cadena + "{}: {}% ".format(num2class[i], int(100*p[i]))
print(cadena)
# Out:
# Clase real: mild
# mild: 35% none: 2% severe: 62%

# %%
# !ls
# Out:
# model_current_best_parte3.h5  seg_test	    seg_train
# sample_data		      seg_test.zip  seg_train.zip

# %%
#from google.colab import files
#files.download('./model_current_best_parte3.h5')

# %% [markdown]
# Se presentan tres tipos de daños, el modelo recono mejor las fotografías con daño severo o no daño, la clase intermedia no la distingue muy bien, por lo que se aprecia suele meter el daño mild en severe.
